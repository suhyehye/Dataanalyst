# %%
import pandas as pd
from pandas import Series, DataFrame

#series 설정
a = Series([1,3,5,7])
print(a)
print(a.values)
print(a.index)

#index 변경
a2 = pd.Series([1,3,5,7],index = ['a','b','c','d'])
print(a2)
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# dtype: int64
# [1 3 5 7]
# RangeIndex(start=0, stop=4, step=1)
# a    1
# b    3
# c    5
# d    7
# dtype: int64

# %%
df=pd.read_csv('EX_GrapeData.csv')
df
# Out:
#     continent  brand  size  period price
# 0           2      2  10.7   47.65   144
# 1           2      3  14.0   63.13   215
# 2           2      2   9.0   58.76   105
# 3           1      1   8.0   34.88    69
# 4           2      2  10.0   55.53   134
# ..        ...    ...   ...     ...   ...
# 58          1      1   5.0   16.66  21.5
# 59          2      1  21.0   43.00
# 60          2      2   5.0   12.00
# 61          2      3  13.0   20.00
# 62          2      3  31.0   19.00
#
# [63 rows x 5 columns]

# %%
df=pd.read_excel('EX_GrapeData.xlsx')
df
# Out:
#     continent  brand  size  period  price
# 0           2      2  10.7   47.65  144.0
# 1           2      3  14.0   63.13  215.0
# 2           2      2   9.0   58.76  105.0
# 3           1      1   8.0   34.88   69.0
# 4           2      2  10.0   55.53  134.0
# ..        ...    ...   ...     ...    ...
# 58          1      1   5.0   16.66   21.5
# 59          2      1  21.0   43.00    NaN
# 60          2      2   5.0   12.00    NaN
# 61          2      3  13.0   20.00    NaN
# 62          2      3  31.0   19.00    NaN
#
# [63 rows x 5 columns]

# %%
#데이터프레임 처음부터 ~개의 행만 불러오기
df.head()
# Out:
#    continent  brand  size  period  price
# 0          2      2  10.7   47.65  144.0
# 1          2      3  14.0   63.13  215.0
# 2          2      2   9.0   58.76  105.0
# 3          1      1   8.0   34.88   69.0
# 4          2      2  10.0   55.53  134.0

# %%
#뒤부터 ~개의 행만 불러오기
df.tail()
# Out:
#     continent  brand  size  period  price
# 58          1      1   5.0   16.66   21.5
# 59          2      1  21.0   43.00    NaN
# 60          2      2   5.0   12.00    NaN
# 61          2      3  13.0   20.00    NaN
# 62          2      3  31.0   19.00    NaN

# %%
#1에서 4까지 출력
df[1:5]
# Out:
#    continent  brand  size  period  price
# 1          2      3  14.0   63.13  215.0
# 2          2      2   9.0   58.76  105.0
# 3          1      1   8.0   34.88   69.0
# 4          2      2  10.0   55.53  134.0

# %%
#처음부터 2까지 출력
df[:3]
# Out:
#    continent  brand  size  period  price
# 0          2      2  10.7   47.65  144.0
# 1          2      3  14.0   63.13  215.0
# 2          2      2   9.0   58.76  105.0

# %%
#60부터 끝까지 출력
df[60:]
# Out:
#     continent  brand  size  period  price
# 60          2      2   5.0    12.0    NaN
# 61          2      3  13.0    20.0    NaN
# 62          2      3  31.0    19.0    NaN

# %%
#price 변수(열) 불러오기 : series 형태
df['price']
#df.frame도가능
# Out:
# 0     144.0
# 1     215.0
# 2     105.0
# 3      69.0
# 4     134.0
#       ...
# 58     21.5
# 59      NaN
# 60      NaN
# 61      NaN
# 62      NaN
# Name: price, Length: 63, dtype: float64

# %%
#price 변수 불러오기 : dataframe 형태
df[['price']]
# Out:
#     price
# 0   144.0
# 1   215.0
# 2   105.0
# 3    69.0
# 4   134.0
# ..    ...
# 58   21.5
# 59    NaN
# 60    NaN
# 61    NaN
# 62    NaN
#
# [63 rows x 1 columns]

# %%
#0,2,4번쨰 열 출력
df[df.columns[[0,2,4]]]
# Out:
#     continent  size  price
# 0           2  10.7  144.0
# 1           2  14.0  215.0
# 2           2   9.0  105.0
# 3           1   8.0   69.0
# 4           2  10.0  134.0
# ..        ...   ...    ...
# 58          1   5.0   21.5
# 59          2  21.0    NaN
# 60          2   5.0    NaN
# 61          2  13.0    NaN
# 62          2  31.0    NaN
#
# [63 rows x 3 columns]

# %%
#size부터 price까지 출력
df.loc[:,'size':'price']
# Out:
#     size  period  price
# 0   10.7   47.65  144.0
# 1   14.0   63.13  215.0
# 2    9.0   58.76  105.0
# 3    8.0   34.88   69.0
# 4   10.0   55.53  134.0
# ..   ...     ...    ...
# 58   5.0   16.66   21.5
# 59  21.0   43.00    NaN
# 60   5.0   12.00    NaN
# 61  13.0   20.00    NaN
# 62  31.0   19.00    NaN
#
# [63 rows x 3 columns]

# %%
#1~7행, 0~2열 불러오기
df.iloc[1:7,0:2]
# Out:
#    continent  brand
# 1          2      3
# 2          2      2
# 3          1      1
# 4          2      2
# 5          2      2
# 6          2      2

# %%
#5행의 price변수 해당 값 불러오기
df.at[5,'price']
# Out:
# 129.0

# %%
#데이터프레임 전체 복사(백업)
df_columns = df.copy()

# %%
#데이터프레임의 열 이름 확인
df_columns.columns
# Out:
# Index(['continent', 'brand', 'size', 'period', 'price'], dtype='object')

# %%
#데이터 프레임 열 필터링
df_columns = df_columns[['size','period','price']]
df_columns.head()
# Out:
#    size  period  price
# 0  10.7   47.65  144.0
# 1  14.0   63.13  215.0
# 2   9.0   58.76  105.0
# 3   8.0   34.88   69.0
# 4  10.0   55.53  134.0

# %%
#데이터 열 이름 수정
df_columns.rename(columns={'period':'time'},inplace=True)
df_columns.columns
# Out:
# Index(['size', 'time', 'price'], dtype='object')

# %%
#size를 time으로 나누어 월별 포도크기로 계산하여 growth 변수 생성
df_columns['growth']=df_columns['size']/df_columns['time']
df_columns.head()
# Out:
#    size   time  price    growth
# 0  10.7  47.65  144.0  0.224554
# 1  14.0  63.13  215.0  0.221765
# 2   9.0  58.76  105.0  0.153165
# 3   8.0  34.88   69.0  0.229358
# 4  10.0  55.53  134.0  0.180083

# %%
#특정변수 삭제
del df_columns['growth']

# %%
#특정 케이스 선택1 : 집단 선택
df_continent_brand=df[(df['continent']==1) & (df['brand']==1)]
df_continent_brand.head()
# Out:
#     continent  brand  size  period  price
# 3           1      1   8.0   34.88   69.0
# 11          1      1  10.4   17.67   54.0
# 12          1      1   7.4   16.41   39.0
# 13          1      1   5.4   12.02   29.5
# 16          1      1   6.0   23.21   42.0

# %%
#특정 케이스 선택2 : 기준값 이상 혹은 이하 선택
df_over_sized_period = df[(df['size']>=10) & (df['period']>=30)]
df_over_sized_period.head()
# Out:
#    continent  brand  size  period  price
# 0          2      2  10.7   47.65  144.0
# 1          2      3  14.0   63.13  215.0
# 4          2      2  10.0   55.53  134.0
# 5          2      2  10.5   43.14  129.0
# 6          2      2  16.0   54.86  155.0

# %%
#brand 범주 카운트
df['brand'].value_counts()
# Out:
# 2    24
# 1    23
# 3    16
# Name: brand, dtype: int64

# %%
#기존의 값을 다른 범주의 값으로 변경
recode_brand = {"brand":{1:1,2:1,3:2}}
df_recode1 = df.replace(recode_brand)
df_recode1.head()
# Out:
#    continent  brand  size  period  price
# 0          2      1  10.7   47.65  144.0
# 1          2      2  14.0   63.13  215.0
# 2          2      1   9.0   58.76  105.0
# 3          1      1   8.0   34.88   69.0
# 4          2      1  10.0   55.53  134.0

# %%
#변경된 결과 확인
df_recode1['brand'].value_counts()
# Out:
# 1    47
# 2    16
# Name: brand, dtype: int64

# %%
#코딩 변경 함수 정의
def brand_groups(series):
    if series ==1:
        return 1
    elif series == 2:
        return 2
    elif series == 3:
        return 2
    
df['re_brand'] = df['brand'].apply(brand_groups)
df.head()
# Out:
#    continent  brand  size  period  price  re_brand
# 0          2      2  10.7   47.65  144.0         2
# 1          2      3  14.0   63.13  215.0         2
# 2          2      2   9.0   58.76  105.0         2
# 3          1      1   8.0   34.88   69.0         1
# 4          2      2  10.0   55.53  134.0         2

# %%
import pandas as pd
df = pd.read_csv('EX_GrapeData.csv')
df.head()
# Out:
#    continent  brand  size  period price
# 0          2      2  10.7   47.65   144
# 1          2      3  14.0   63.13   215
# 2          2      2   9.0   58.76   105
# 3          1      1   8.0   34.88    69
# 4          2      2  10.0   55.53   134

# %%
#판다스 넘파이로 변환
df_num=df.to_numpy()
df_num

#변수명이 없고 모두 숫자로 이루어짐
# Out:
# array([[2, 2, 10.7, 47.65, '144'],
#        [2, 3, 14.0, 63.13, '215'],
#        [2, 2, 9.0, 58.76, '105'],
#        [1, 1, 8.0, 34.88, '69'],
#        [2, 2, 10.0, 55.53, '134'],
#        [2, 2, 10.5, 43.14, '129'],
#        [2, 2, 16.0, 54.86, '155'],
#        [2, 1, 15.0, 44.14, '99'],
#        [2, 1, 6.5, 17.46, '38.5'],
#        [2, 1, 5.0, 21.04, '36.5'],
#        [2, 2, 25.0, 109.38, '260'],
#        [1, 1, 10.4, 17.67, '54'],
#        [1, 1, 7.4, 16.41, '39'],
#        [1, 1, 5.4, 12.02, '29.5'],
#        [2, 2, 15.4, 49.48, '109'],
#        [2, 1, 12.4, 48.74, '89.5'],
#        [1, 1, 6.0, 23.21, '42'],
#        [1, 1, 9.0, 28.64, '65'],
#        [1, 3, 9.0, 44.95, '115'],
#        [1, 1, 12.4, 23.77, '49.5'],
#        [1, 1, 7.5, 20.21, '36.5'],
#        [1, 3, 14.0, 32.62, '109'],
#        [1, 1, 7.0, 17.84, '45'],
#        [1, 2, 9.0, 22.82, '58'],
#        [1, 2, 12.0, 29.48, '89'],
#        [1, 1, 5.5, 15.61, '30'],
#        [1, 2, 6.0, 13.25, '31'],
#        [1, 3, 12.0, 45.78, '119'],
#        [2, 1, 5.5, 26.53, '22'],
#        [1, 3, 14.2, 37.11, '109'],
#        [2, 2, 11.0, 45.12, '99'],
#        [1, 2, 16.0, 26.09, '99'],
#        [2, 3, 13.5, 68.63, '179'],
#        [2, 2, 11.1, 33.71, '99'],
#        [2, 3, 9.8, 44.45, '89'],
#        [1, 2, 10.0, 23.74, '75'],
#        [2, 3, 13.0, 86.42, '199'],
#        [1, 3, 13.0, 39.71, '93'],
#        [1, 2, 11.7, 26.52, '65'],
#        [2, 2, 12.3, 33.89, '74'],
#        [2, 3, 19.5, 64.3, '165'],
#        [1, 3, 15.2, 22.55, '99'],
#        [1, 1, 10.0, 31.86, '43.5'],
#        [1, 3, 11.0, 53.18, '94'],
#        [2, 3, 17.8, 74.48, '189'],
#        [2, 2, 11.5, 34.16, '75'],
#        [2, 1, 12.7, 31.46, '59.5'],
#        [1, 1, 8.0, 21.34, '42'],
#        [2, 1, 7.5, 20.83, '23'],
#        [1, 2, 9.0, 20.59, '52.5'],
#        [2, 2, 14.0, 33.7, '99'],
#        [2, 2, 12.4, 32.9, '89'],
#        [2, 2, 8.8, 27.76, '65'],
#        [1, 1, 8.5, 30.2, '54.5'],
#        [1, 1, 6.0, 20.85, '24.5'],
#        [1, 2, 11.0, 26.25, '52'],
#        [1, 2, 11.1, 21.87, '62.5'],
#        [1, 3, 14.5, 23.88, '89'],
#        [1, 1, 5.0, 16.66, '21.5'],
#        [2, 1, 21.0, 43.0, ' '],
#        [2, 2, 5.0, 12.0, ' '],
#        [2, 3, 13.0, 20.0, ' '],
#        [2, 3, 31.0, 19.0, ' ']], dtype=object)

# %%
#넘파이를 판다스로 변환
df_pd = pd.DataFrame(df_num)
df_pd.head()
# Out:
#    0  1     2      3    4
# 0  2  2  10.7  47.65  144
# 1  2  3  14.0  63.13  215
# 2  2  2   9.0  58.76  105
# 3  1  1   8.0  34.88   69
# 4  2  2  10.0  55.53  134

# %%
#판다스로 변환하면서 변수이름도 함께 지정
df_pd2 = pd.DataFrame(data = df_num, columns = ["continent","brand","size","period","price"])
df_pd2.head()
# Out:
#   continent brand  size period price
# 0         2     2  10.7  47.65   144
# 1         2     3  14.0  63.13   215
# 2         2     2   9.0  58.76   105
# 3         1     1   8.0  34.88    69
# 4         2     2  10.0  55.53   134
